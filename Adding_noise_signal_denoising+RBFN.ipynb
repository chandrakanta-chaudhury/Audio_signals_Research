# %% [markdown]
# <a href="https://colab.research.google.com/github/chandrakanta-chaudhury/Audio_signals_Research/blob/master/Adding_noise_signal_denoising%2BRBFN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Data has been used from http://groups.inf.ed.ac.uk/ami/download/

# %%
# !wget http://groups.inf.ed.ac.uk/ami/download/temp/amiBuild-175215-Wed-Apr-29-2020.wget.sh
# Out:
# --2020-04-30 05:09:45--  http://groups.inf.ed.ac.uk/ami/download/temp/amiBuild-175215-Wed-Apr-29-2020.wget.sh
# Resolving groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)... 129.215.202.26
# Connecting to groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)|129.215.202.26|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2234 (2.2K) [application/x-sh]
# Saving to: ‘amiBuild-175215-Wed-Apr-29-2020.wget.sh’
#
# amiBuild-175215-Wed 100%[===================>]   2.18K  --.-KB/s    in 0s
#
# 2020-04-30 05:09:46 (368 MB/s) - ‘amiBuild-175215-Wed-Apr-29-2020.wget.sh’ saved [2234/2234]

# %%
# !sh amiBuild-175215-Wed-Apr-29-2020.wget.sh
# Out:
# --2020-04-30 05:09:56--  http://groups.inf.ed.ac.uk/ami/AMICorpusMirror//amicorpus/ES2007a/audio/ES2007a.Array1-01.wav
# Resolving groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)... 129.215.202.26
# Connecting to groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)|129.215.202.26|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38601772 (37M) [audio/x-wav]
# Saving to: ‘amicorpus/ES2007a/audio/ES2007a.Array1-01.wav’
#
# ES2007a.Array1-01.w 100%[===================>]  36.81M  2.70MB/s    in 14s
#
# 2020-04-30 05:10:13 (2.61 MB/s) - ‘amicorpus/ES2007a/audio/ES2007a.Array1-01.wav’ saved [38601772/38601772]
#
# --2020-04-30 05:10:13--  http://groups.inf.ed.ac.uk/ami/AMICorpusMirror//amicorpus/ES2007a/audio/ES2007a.Array1-02.wav
# Resolving groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)... 129.215.202.26
# Connecting to groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)|129.215.202.26|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38601772 (37M) [audio/x-wav]
# Saving to: ‘amicorpus/ES2007a/audio/ES2007a.Array1-02.wav’
#
# ES2007a.Array1-02.w 100%[===================>]  36.81M  3.55MB/s    in 14s
#
# 2020-04-30 05:10:27 (2.59 MB/s) - ‘amicorpus/ES2007a/audio/ES2007a.Array1-02.wav’ saved [38601772/38601772]
#
# --2020-04-30 05:10:27--  http://groups.inf.ed.ac.uk/ami/AMICorpusMirror//amicorpus/ES2007a/audio/ES2007a.Array1-03.wav
# Resolving groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)... 129.215.202.26
# Connecting to groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)|129.215.202.26|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38601772 (37M) [audio/x-wav]
# Saving to: ‘amicorpus/ES2007a/audio/ES2007a.Array1-03.wav’
#
# ES2007a.Array1-03.w 100%[===================>]  36.81M  2.79MB/s    in 18s
#
# 2020-04-30 05:10:47 (2.01 MB/s) - ‘amicorpus/ES2007a/audio/ES2007a.Array1-03.wav’ saved [38601772/38601772]
#
# --2020-04-30 05:10:47--  http://groups.inf.ed.ac.uk/ami/AMICorpusMirror//amicorpus/ES2007a/audio/ES2007a.Array1-04.wav
# Resolving groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)... 129.215.202.26
# Connecting to groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)|129.215.202.26|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38601772 (37M) [audio/x-wav]
# Saving to: ‘amicorpus/ES2007a/audio/ES2007a.Array1-04.wav’
#
# ES2007a.Array1-04.w 100%[===================>]  36.81M  1.59MB/s    in 25s
#
# 2020-04-30 05:11:13 (1.49 MB/s) - ‘amicorpus/ES2007a/audio/ES2007a.Array1-04.wav’ saved [38601772/38601772]
#
# --2020-04-30 05:11:13--  http://groups.inf.ed.ac.uk/ami/AMICorpusMirror//amicorpus/ES2007a/audio/ES2007a.Array1-05.wav
# Resolving groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)... 129.215.202.26
# Connecting to groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)|129.215.202.26|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38601772 (37M) [audio/x-wav]
# Saving to: ‘amicorpus/ES2007a/audio/ES2007a.Array1-05.wav’
#
# ES2007a.Array1-05.w 100%[===================>]  36.81M  3.10MB/s    in 16s
#
# 2020-04-30 05:11:31 (2.25 MB/s) - ‘amicorpus/ES2007a/audio/ES2007a.Array1-05.wav’ saved [38601772/38601772]
#
# --2020-04-30 05:11:31--  http://groups.inf.ed.ac.uk/ami/AMICorpusMirror//amicorpus/ES2007a/audio/ES2007a.Array1-06.wav
# Resolving groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)... 129.215.202.26
# Connecting to groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)|129.215.202.26|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38601772 (37M) [audio/x-wav]
# Saving to: ‘amicorpus/ES2007a/audio/ES2007a.Array1-06.wav’
#
# ES2007a.Array1-06.w 100%[===================>]  36.81M  3.71MB/s    in 14s
#
# 2020-04-30 05:11:45 (2.73 MB/s) - ‘amicorpus/ES2007a/audio/ES2007a.Array1-06.wav’ saved [38601772/38601772]
#
# --2020-04-30 05:11:45--  http://groups.inf.ed.ac.uk/ami/AMICorpusMirror//amicorpus/ES2007a/audio/ES2007a.Array1-07.wav
# Resolving groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)... 129.215.202.26
# Connecting to groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)|129.215.202.26|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38601772 (37M) [audio/x-wav]
# Saving to: ‘amicorpus/ES2007a/audio/ES2007a.Array1-07.wav’
#
# ES2007a.Array1-07.w 100%[===================>]  36.81M  3.04MB/s    in 14s
#
# 2020-04-30 05:11:59 (2.65 MB/s) - ‘amicorpus/ES2007a/audio/ES2007a.Array1-07.wav’ saved [38601772/38601772]
#
# --2020-04-30 05:11:59--  http://groups.inf.ed.ac.uk/ami/AMICorpusMirror//amicorpus/ES2007a/audio/ES2007a.Array1-08.wav
# Resolving groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)... 129.215.202.26
# Connecting to groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)|129.215.202.26|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38601772 (37M) [audio/x-wav]
# Saving to: ‘amicorpus/ES2007a/audio/ES2007a.Array1-08.wav’
#
# ES2007a.Array1-08.w 100%[===================>]  36.81M  4.00MB/s    in 10s
#
# 2020-04-30 05:12:10 (3.68 MB/s) - ‘amicorpus/ES2007a/audio/ES2007a.Array1-08.wav’ saved [38601772/38601772]
#
# --2020-04-30 05:12:10--  http://groups.inf.ed.ac.uk/ami/AMICorpusMirror//amicorpus/ES2007a/audio/ES2007a.Array2-01.wav
# Resolving groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)... 129.215.202.26
# Connecting to groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)|129.215.202.26|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38601772 (37M) [audio/x-wav]
# Saving to: ‘amicorpus/ES2007a/audio/ES2007a.Array2-01.wav’
#
# ES2007a.Array2-01.w 100%[===================>]  36.81M  7.34MB/s    in 7.0s
#
# 2020-04-30 05:12:18 (5.25 MB/s) - ‘amicorpus/ES2007a/audio/ES2007a.Array2-01.wav’ saved [38601772/38601772]
#
# --2020-04-30 05:12:18--  http://groups.inf.ed.ac.uk/ami/AMICorpusMirror//amicorpus/ES2007a/audio/ES2007a.Array2-02.wav
# Resolving groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)... 129.215.202.26
# Connecting to groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)|129.215.202.26|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38601772 (37M) [audio/x-wav]
# Saving to: ‘amicorpus/ES2007a/audio/ES2007a.Array2-02.wav’
#
# ES2007a.Array2-02.w 100%[===================>]  36.81M  2.72MB/s    in 14s
#
# 2020-04-30 05:12:33 (2.70 MB/s) - ‘amicorpus/ES2007a/audio/ES2007a.Array2-02.wav’ saved [38601772/38601772]
#
# --2020-04-30 05:12:33--  http://groups.inf.ed.ac.uk/ami/AMICorpusMirror//amicorpus/ES2007a/audio/ES2007a.Array2-03.wav
# Resolving groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)... 129.215.202.26
# Connecting to groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)|129.215.202.26|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38601772 (37M) [audio/x-wav]
# Saving to: ‘amicorpus/ES2007a/audio/ES2007a.Array2-03.wav’
#
# ES2007a.Array2-03.w 100%[===================>]  36.81M  2.19MB/s    in 17s
#
# 2020-04-30 05:12:51 (2.13 MB/s) - ‘amicorpus/ES2007a/audio/ES2007a.Array2-03.wav’ saved [38601772/38601772]
#
# --2020-04-30 05:12:51--  http://groups.inf.ed.ac.uk/ami/AMICorpusMirror//amicorpus/ES2007a/audio/ES2007a.Array2-04.wav
# Resolving groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)... 129.215.202.26
# Connecting to groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)|129.215.202.26|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38601772 (37M) [audio/x-wav]
# Saving to: ‘amicorpus/ES2007a/audio/ES2007a.Array2-04.wav’
#
# ES2007a.Array2-04.w 100%[===================>]  36.81M  2.86MB/s    in 17s
#
# 2020-04-30 05:13:10 (2.14 MB/s) - ‘amicorpus/ES2007a/audio/ES2007a.Array2-04.wav’ saved [38601772/38601772]
#
# --2020-04-30 05:13:10--  http://groups.inf.ed.ac.uk/ami/AMICorpusMirror//amicorpus/ES2007a/audio/ES2007a.Array2-05.wav
# Resolving groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)... 129.215.202.26
# Connecting to groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)|129.215.202.26|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38601772 (37M) [audio/x-wav]
# Saving to: ‘amicorpus/ES2007a/audio/ES2007a.Array2-05.wav’
#
# ES2007a.Array2-05.w 100%[===================>]  36.81M  2.80MB/s    in 16s
#
# 2020-04-30 05:13:27 (2.29 MB/s) - ‘amicorpus/ES2007a/audio/ES2007a.Array2-05.wav’ saved [38601772/38601772]
#
# --2020-04-30 05:13:27--  http://groups.inf.ed.ac.uk/ami/AMICorpusMirror//amicorpus/ES2007a/audio/ES2007a.Array2-06.wav
# Resolving groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)... 129.215.202.26
# Connecting to groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)|129.215.202.26|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38601772 (37M) [audio/x-wav]
# Saving to: ‘amicorpus/ES2007a/audio/ES2007a.Array2-06.wav’
#
# ES2007a.Array2-06.w 100%[===================>]  36.81M  2.94MB/s    in 14s
#
# 2020-04-30 05:13:42 (2.56 MB/s) - ‘amicorpus/ES2007a/audio/ES2007a.Array2-06.wav’ saved [38601772/38601772]
#
# --2020-04-30 05:13:42--  http://groups.inf.ed.ac.uk/ami/AMICorpusMirror//amicorpus/ES2007a/audio/ES2007a.Array2-07.wav
# Resolving groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)... 129.215.202.26
# Connecting to groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)|129.215.202.26|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38601772 (37M) [audio/x-wav]
# Saving to: ‘amicorpus/ES2007a/audio/ES2007a.Array2-07.wav’
#
# ES2007a.Array2-07.w 100%[===================>]  36.81M  2.70MB/s    in 18s
#
# 2020-04-30 05:14:01 (2.05 MB/s) - ‘amicorpus/ES2007a/audio/ES2007a.Array2-07.wav’ saved [38601772/38601772]
#
# --2020-04-30 05:14:01--  http://groups.inf.ed.ac.uk/ami/AMICorpusMirror//amicorpus/ES2007a/audio/ES2007a.Array2-08.wav
# Resolving groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)... 129.215.202.26
# Connecting to groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)|129.215.202.26|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38601772 (37M) [audio/x-wav]
# Saving to: ‘amicorpus/ES2007a/audio/ES2007a.Array2-08.wav’
#
# ES2007a.Array2-08.w 100%[===================>]  36.81M  3.34MB/s    in 12s
#
# 2020-04-30 05:14:14 (3.01 MB/s) - ‘amicorpus/ES2007a/audio/ES2007a.Array2-08.wav’ saved [38601772/38601772]
#
# --2020-04-30 05:14:14--  http://groups.inf.ed.ac.uk/ami/download/temp/amiBuild-175215-Wed-Apr-29-2020.manifest.txt
# Resolving groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)... 129.215.202.26
# Connecting to groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)|129.215.202.26|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1769 (1.7K) [text/plain]
# Saving to: ‘amiBuild-175215-Wed-Apr-29-2020.manifest.txt’
#
# amiBuild-175215-Wed 100%[===================>]   1.73K  --.-KB/s    in 0s
#
# 2020-04-30 05:14:14 (441 MB/s) - ‘amiBuild-175215-Wed-Apr-29-2020.manifest.txt’ saved [1769/1769]
#
# --2020-04-30 05:14:14--  http://groups.inf.ed.ac.uk/ami/download/CCBY4.0.txt
# Resolving groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)... 129.215.202.26
# Connecting to groups.inf.ed.ac.uk (groups.inf.ed.ac.uk)|129.215.202.26|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17026 (17K) [text/plain]
# Saving to: ‘CCBY4.0.txt’
#
# CCBY4.0.txt         100%[===================>]  16.63K  --.-KB/s    in 0.1s
#
# 2020-04-30 05:14:15 (158 KB/s) - ‘CCBY4.0.txt’ saved [17026/17026]

# %%
#checking GPU in my colab

# !nvidia-smi
# Out:
# Thu Apr 30 05:14:18 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import librosa
from glob import glob
import numpy as np
import matplotlib.pyplot as plt

# loop over all files in the current directory ending with .txt
for fname in glob("/content/amicorpus/ES2007a/audio/ES2007a.Array1-0*.wav"):
  x , sr = librosa.load(fname)
  import librosa.display
  plt.figure(figsize=(14, 5))
  librosa.display.waveplot(x,sr=sr)

# %%
x.shape
# Out:
# (26599004,)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Layer
from tensorflow.keras.initializers import RandomUniform, Initializer, Constant

# %%
 
#given a signal and desired SNR, this gives the required AWGN what should be added to the signal to get the desired SNR
def get_white_noise(signal,SNR) :
    #RMS value of signal
    RMS_s=math.sqrt(np.mean(signal**2))
    #RMS values of noise
    RMS_n=math.sqrt(RMS_s**2/(pow(10,SNR/20)))
    #Additive white gausian noise. Thereore mean=0
    #Because sample length is large (typically > 40000)
    #we can use the population formula for standard daviation.
    #because mean=0 STD=RMS
    STD_n=RMS_n
    noise=np.random.normal(0, STD_n, signal.shape[0])
    return noise

# %%
import math
signal=np.interp(x, (x.min(), x.max()), (-1, 1))
noise=get_white_noise(signal,SNR=10)

# %%
##for all signals with added noise plotting 
from glob import glob
X = []
pad = lambda a, i: a[0: i] if a.shape[0] > i else np.hstack((a, np.zeros(i - a.shape[0])))
import matplotlib.pyplot as plt
for fname in glob("/content/amicorpus/ES2007a/audio/ES2007a.Array1-0*.wav"):
  x , sr = librosa.load(fname)
  signal=np.interp(x, (x.min(), x.max()), (-1, 1))
  noise=get_white_noise(signal,SNR=10)
  signal_noise=signal+noise
  padded = pad(signal_noise, 3000)
  X.append(padded)
  fig, ax = plt.subplots(figsize=(10,4))
  ax.plot(signal_noise)
  #plt.plot(signal_noise)

# %%
#add the signal to noise for one of the signal
#signal_noise=signal+noise

# %%
#plotting a single  noise added signal
import matplotlib.pyplot as plt
plt.plot(signal_noise)
plt.xlabel("Sample number")
plt.ylabel("Amplitude")
plt.show()

# %%
X=np.vstack(X)

# %%
# type(signal_noise)
X.shape
# Out:
# (8, 3000)

# %%
#X=signal_noise.reshape((1,26599004))

# %%
#X.shape
# Out:
# (1, 26599004)

# %%
#as system getting crashed due to the array size 
#X1=signal_noise[-3000:]
#X=X1.reshape((1,3000))

# %%
#X.shape
# Out:
# (1, 3000)

# %%
#use RBFN to denise 
#new way RBF 
class RBFLayer(Layer):
    def __init__(self, units, gamma, **kwargs):
        super(RBFLayer, self).__init__(**kwargs)
        self.units = units
        self.gamma = K.cast_to_floatx(gamma)

    def build(self, input_shape):
#         print(input_shape)
#         print(self.units)
        self.mu = self.add_weight(name='mu',
                                  shape=(int(input_shape[1]), self.units),
                                  initializer='uniform',
                                  trainable=True)
        super(RBFLayer, self).build(input_shape)

    def call(self, inputs):
        diff = K.expand_dims(inputs) - self.mu
        l2 = K.sum(K.pow(diff, 2), axis=1)
        res = K.exp(-1 * self.gamma * l2)
        return res

    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.units)

# %%
from tensorflow.keras.layers import Flatten
model = Sequential()
model.add(Flatten(input_shape=(1,X.shape[1])))
model.add(RBFLayer(100, 0.5))

# %%
model.add(RBFLayer(3000, 0.5))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 3000)              0
# _________________________________________________________________
# rbf_layer (RBFLayer)         (None, 100)               300000
# _________________________________________________________________
# rbf_layer_1 (RBFLayer)       (None, 3000)              300000
# =================================================================
# Total params: 600,000
# Trainable params: 600,000
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy')

# %%
#cmmenting as i have only single signal file to check the model , so training and test i kept same
from sklearn.model_selection import train_test_split
X_train, X_test = train_test_split(X, test_size=0.2)

# %%
X_train.shape,X_test.shape
# Out:
# ((6, 3000), (2, 3000))

# %%
model.fit(X_train,X_train,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(X_test, X_test))
# Out:
# Epoch 1/100
# WARNING:tensorflow:Model was constructed with shape (None, 1, 3000) for input Tensor("flatten_input:0", shape=(None, 1, 3000), dtype=float32), but it was called on an input with incompatible shape (None, 3000).
# WARNING:tensorflow:Model was constructed with shape (None, 1, 3000) for input Tensor("flatten_input:0", shape=(None, 1, 3000), dtype=float32), but it was called on an input with incompatible shape (None, 3000).
# Epoch 83/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4490 - val_loss: 1.1953
# Epoch 84/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4448 - val_loss: 1.1852
# Epoch 85/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4405 - val_loss: 1.1752
# Epoch 86/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4363 - val_loss: 1.1653
# Epoch 87/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4322 - val_loss: 1.1555
# Epoch 88/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4281 - val_loss: 1.1458
# Epoch 89/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4240 - val_loss: 1.1362
# Epoch 90/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4199 - val_loss: 1.1268
# Epoch 91/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4159 - val_loss: 1.1174
# Epoch 92/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4120 - val_loss: 1.1082
# Epoch 93/100
# 1/1 [==============================] - 0s 166ms/step - loss: 0.4080 - val_loss: 1.0990
# Epoch 94/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4041 - val_loss: 1.0900
# Epoch 95/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4003 - val_loss: 1.0811
# Epoch 96/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3964 - val_loss: 1.0722
# Epoch 97/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3926 - val_loss: 1.0635
# Epoch 98/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3888 - val_loss: 1.0548
# Epoch 99/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3851 - val_loss: 1.0462
# Epoch 100/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3814 - val_loss: 1.0378

# %%
#y=X.reshape(1,1,3000)
y=model.predict(X_test)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 1, 3000) for input Tensor("flatten_input:0", shape=(None, 1, 3000), dtype=float32), but it was called on an input with incompatible shape (None, 3000).

# %%
y.shape,
print(y)
# Out:
# [[0.65019816 0.65699166 0.6505881  ... 0.6572374  0.65129614 0.65235484]
#  [0.6446978  0.6568449  0.649935   ... 0.65542156 0.6515841  0.6505631 ]]

# %%
for i in range(y.shape[0]):
  #give full path here before file_  ex - give local path of ur system if needed
  f = open("file_"+str(i)+".wav","wb")
  data=y[i]
  librosa.output.write_wav(f,data,sr=sr)

# %%
#after removing noise using RBF natwork this is cleanded signals for 2 test wav signal files
import librosa
import librosa.display
#librosa.display.waveplot(y,sr=sr)
#change path here if u r having local path , wherever ur file is 
for fname in glob("/content/file_*.wav"):
  print(fname)
  x1 , sr = librosa.load(fname)
  plt.figure(figsize=(10, 5))
  librosa.display.waveplot(x1,sr=sr)
# Out:
# /content/file_1.wav
# /content/file_0.wav
